# %% [markdown]
# <a href="https://colab.research.google.com/github/Re14m/training/blob/master/2022-0317_recipie135.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # [GPT-3でタイトルや要約から記事本文を自動生成するレシピ](https://axross-recipe.com/recipes/135)

# %%
# パッケージのインストール
# !pip install openai

# %%
# !python main.py
