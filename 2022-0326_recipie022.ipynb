# %% [markdown]
# <a href="https://colab.research.google.com/github/Re14m/training/blob/master/2022-0326_recipie022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # [科学のニュース記事を分類するレシピ](https://axross-recipe.com/recipes/022)

# %%
# パッケージのインストール
# !pip install scikit-learn==0.23.2

# %%
# バージョン確認（python）
import platform
print("python " + platform.python_version())

# %%
# datasetの読込
from sklearn.datasets import fetch_20newsgroups
train = fetch_20newsgroups(subset='train')

# %%
# datasetの確認
train.target_names

# %%
# datasetからカテゴリ指定して抽出
categories=['sci.crypt', 'sci.electronics', 'sci.med', 'sci.space']
train = fetch_20newsgroups(subset='train', categories=categories)

# %%
# datasetのサイズ確認
print(len(train.data))  # train.data=ニュース記事のテキスト
print(len(train.target))  # train.target=ニュース記事のテキストに対する正解ラベル

# %%
# ニュース記事のテキストを確認
print(train.data[0])

# %%
# ニュース記事のラベルを確認
train.target[0] # ラベルが0=分類が0

# %%
# 分類をすべて表示
train.target_names

# %%
# 記事のラベルから分類名を表示
train.target_names[train.target[0]]

# %%
# テキストの最適化（TS-IDF）
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
X_train = vectorizer.fit_transform(train.data).toarray()
print(len(vectorizer.get_feature_names()))
print(X_train)
print(X_train.shape)

# %%
# 訓練（RandomForest）

# 分類器の生成
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier()

# %%
# 訓練の実施
clf.fit(X_train, train.target) # fitの第一引数に訓練データセットの特徴量、第二引数に訓練データセットの正解ラベルを指定

# %%
# 精度の検証

# testdatasetの読込
test = fetch_20newsgroups(subset='test', categories=categories)

# %%
# TS-IDFで数値化
X_test = vectorizer.transform(test.data).toarray()
X_test.shape

# %%
# testdataと分類器で予測
preds = clf.predict(X_test)
preds

# %%
# 訓練した分類器の正解率を計算（Accurancy）
from sklearn.metrics import accuracy_score
accuracy_score(test.target, preds)
