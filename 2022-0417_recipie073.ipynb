# %% [markdown]
# <a href="https://colab.research.google.com/github/Re14m/training/blob/master/2022-0417_recipie073.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # [GPUを使用せずに機械学習モデルで顔画像を分類するレシピ](https://axross-recipe.com/recipes/073)

# %%
# パッケージのインストール
# !pip install scikit-learn==0.23.2 matplotlib==3.3.2

# %%
# Pythonのバージョン確認
import platform
print("python " + platform.python_version())

# %%
# dataset読込
from sklearn.datasets import fetch_olivetti_faces
data = fetch_olivetti_faces()

# %%
# datasetの表示
data

# %%
# datasetのサイズを確認
print(data.images.shape)
print(data.data.shape)
print(data.target.shape)

# %%
# images[0]をデータとして表示
data.images[0]

# %%
# images[0]を画像として表示
import matplotlib.pyplot as plt
plt.imshow(data.images[0], cmap = "gray")
plt.show()

# %%
# images[0]に対する正解ラベル
data.target[0]

# %%
# images[10]を画像として表示
plt.imshow(data.images[10], cmap = "gray")
plt.show()

# %%
# images[10]に対する正解ラベル
data.target[10]

# %%
# datasetを分割する
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data.data, data.target, test_size=0.2, shuffle=True, stratify=data.target, random_state=0)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)

# %%
# 訓練データの正解ラベルを確認する
from collections import Counter
print(Counter(y_train))

# %%
# 分類器の生成
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(random_state=0)

# %%
# 訓練
clf.fit(X_train, y_train)

# %%
# 精度の検証（分類器の予測）
y_pred = clf.predict(X_test)
y_pred

# %%
# 精度の検証（分類器の正解率）
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)

# %%
# 分類器の性能分析（混同行列）
from sklearn.metrics import plot_confusion_matrix
fig, ax = plt.subplots(figsize=(16, 16))
plot_confusion_matrix(clf, X_test, y_test, ax=ax)
plt.show()
